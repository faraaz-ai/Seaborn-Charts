# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt#matplot is used because plt.show is used here 

data={"Days":[1,2,3,4,5],
      "NOP":[50,40,60,30,44]}

df=pd.DataFrame(data)
print(df)

sns.lineplot(data= data,x="Days",y="NOP")
plt.show()
# Out:
#    Days  NOP
# 0     1   50
# 1     2   40
# 2     3   60
# 3     4   30
# 4     5   44
